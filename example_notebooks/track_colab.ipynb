# %%
checkpoint_dir = "/Users/kerekovskik/Library/CloudStorage/GoogleDrive-kerekovskik@gmail.com/My Drive/colab_data/projects/nlp/transformer_checkpoints_multi_gpu_with_lr"

# %%
from krk_ml_utils import eda
import os 

scale_factor = 1.5
eda.plot_step_training_metrics(
    checkpoint_dir=checkpoint_dir,
    save_plots=False,
    figsize=(10*scale_factor, 6*scale_factor),
    start_step=40000,
    #end_step=100000,
)
# Out:
# Filtered metrics to steps 40000 to 212000
# Actual min/max global_step in filtered data: 40000 to 212000
# /Users/kerekovskik/repos/jax/krk_ml_utils/krk_ml_utils/eda.py:1824: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="best", frameon=True, fancybox=True, shadow=True)
# /Users/kerekovskik/repos/jax/krk_ml_utils/krk_ml_utils/eda.py:1918: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="best")
